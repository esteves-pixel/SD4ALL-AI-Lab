# %% [markdown]
# <a href="https://colab.research.google.com/github/esteves-pixel/SD4ALL-AI-Lab/blob/main/hello_gpu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch, platform
print("CUDA available?", torch.cuda.is_available(), "| PyTorch", torch.__version__)
# Out:
# CUDA available? True | PyTorch 2.6.0+cu124
